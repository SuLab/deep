# %% [markdown]
# ## looking at a single journal article in CoNLL-X format
#
# Data from http://deepdive.stanford.edu/doc/opendata/

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn
import numpy as np
import pandas as pd

seaborn.set()

# %%
df = pd.read_csv('journal.pbio.0000001.pdf.nlp', sep='\t', header=None, names=['ID', 'FORM', 'POSTAG', 'NERTAG', 'LEMMA', 'DEPREL', 'HEAD', 'SENTID', 'PROV'])
df
# Out:
#        ID            FORM POSTAG  NERTAG           LEMMA   DEPREL  HEAD  \
# 0       1            PLOS    NNP       O            PLOS       nn     2
# 1       2         BIOLOGY    NNP       O         BIOLOGY        _     0
# 2       1               A     DT       O               a      det     3
# 3       2      Functional     JJ       O      functional     amod     3
# 4       3        Analysis     NN       O        analysis        _     0
# 5       4              of     IN       O              of        _     0
# 6       5             the     DT       O             the      det     6
# 7       6          Spacer     NN       O          spacer  prep_of     3
# 8       7              of     IN       O              of        _     0
# 9       8               V     NN       O               v       nn    10
# 10      9               (     NN       O               (       nn    10
# 11     10               D     NN       O               d  prep_of     6
# ...

# %%
df['POSTAG'].value_counts()
# Out:
# NN       3730
# CD       1428
# IN       1302
# DT       1075
# NNS       814
# JJ        781
# NNP       757
# .         682
# ,         608
# CC        379
# VBN       329
# RB        313
# :         257
# VBP       229
# FW        225
# VBZ       223
# VBD       164
# TO        164
# VBG       141
# VB        134
# PRP        66
# WDT        56
# MD         46
# PRP$       43
# JJR        40
# SYM        25
# ''         22
# JJS        18
# RBR        15
# WRB        14
# RBS         9
# NNPS        8
# LS          7
# punct       7
# WP$         3
# RP          2
# PDT         2
# POS         2
# EX          2
# WP          2
# dep         1
# $           1
# Name: POSTAG, dtype: int64

# %%
df['NERTAG'].value_counts()
# Out:
# O               12137
# NUMBER           1258
# PERSON            251
# DATE              201
# ORGANIZATION      145
# MISC               38
# LOCATION           34
# ORDINAL            19
# PERCENT            17
# DURATION           11
# MONEY               6
# 9                   2
# 1                   2
# 25                  1
# TIME                1
# 2                   1
# 11                  1
# 27                  1
# Name: NERTAG, dtype: int64
